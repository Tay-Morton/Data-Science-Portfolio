# %% [markdown]
# # Web Scraping, Data Cleaning, and Sentiment Analysis: Salar in Downtown Dayton

# %% [markdown]
# ### Importing our Packages

# %%
# we will use pandas create our data frame
import pandas as pd
# we will use Beautiful Soup fromto pull data from the HTML
from bs4 import BeautifulSoup
# requests will allow us to pull data from Yelp
import requests
# use to perform numerical operations
import numpy as np

# %% [markdown]
# ###### The *Requests* function will allow us to make request to yelp.

# %%
r = requests.get('https://www.yelp.com/biz/roost-italian-dayton')
print(r)
# Out:
# <Response [200]>

# %%
print(r.status_code)
# Out:
# 200

# %%
r.text
# Out:
# '<!DOCTYPE HTML>\n\n<!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->\n<!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="no-js" lang="en"> <!--<![endif]-->\n    <head>\n        <script nonce="a6750959">\n            (function() {\n                var main = null;\n\n                var main=function(){window.onerror=function(k,a,c,i,f){var j=(document.getElementsByTagName("html")[0].getAttribute("webdriver")==="true"||navigator.userAgent==="selenium");var h=f&&(f.name==="ServerSideRenderingError"||f.name==="CSRFallbackError");if(j&&!h){document.body.innerHTML="<h1>Javascript Error Detected</h1>";var g=document.createElement("div");g.setAttribute("id","pastebinTraceback");var d=document.createElement("code");var e={message:k,source:a,lineno:c,colno:i,error:f};var b=document.createTextNode("JS ERROR DETECTED\\n"+window.JSON.stringify(e,null,2));\nd.appendChild(b);g.appendChild(d);document.getElementsByTagName("body")[0].appendChild(g)}}};\n\n                if (main === null) {\n                    throw \'invalid inline script, missing main declaration.\';\n                }\n                main();\n            })();\n    </script>\n\n\n                    <link href="https://s3-media0.fl.yelpcdn.com" rel="dns-prefetch">\n        <link href="https://www.google.com" rel="dns-prefetch">\n        <link href="https://www.google-analytics.com" rel="dns-prefetch">\n        <link href="https://www.facebook.com" rel="dns-prefetch">\n        <link href="https://connect.facebook.net" rel="dns-prefetch">\n        <link href="https://maps.googleapis.com" rel="dns-prefetch">\n        <link href="https://js.adsrvr.org" rel="dns-prefetch">\n        <link href="https://stats.g.doubleclick.net" rel="dns-prefetch">\n        <link href="https://idsync.rlcdn.com" rel="dns-prefetch">\n\n\n    <script>            window.yPageStart = new Date().getTime();\n</script>\n\n    <script>            var initialVisibilityState = document.webkitVisibilityState;\n\n                yPerfTimings = [];\n\n                ySitRepParams = {"uniqueRequestID": "a6750959739bea50", "zipkinTraceID": "9309b287104445c9", "cfRayID": null, "yuv_record": "GTWtXW9hE4OYFo24qgodbpsQg98O1QLtILYDZSvJQLdml45AqwymKkhSkfYef25mulmusLJgMbtMEfd15wuGyZKuQ83sVJaj", "serverStartTime": 1628976345549, "datacenter": "us-east-1", "site": "main", "isLoggedIn": false, "action": null, "servlet": "biz_details", "clientIP": "12.246.51.142", "is_internal_ip": false, "edgeStartTime": 1628976345537620, "b3Sampled": "0", "edgestageSubdomain": "_disabled", "disableBeacon": false};\n                window.ySitRepParams[\'initialVisibilityState\'] = initialVisibilityState;\n                window.ySitRepParams[\'seoCohorts\'] = [["amp_biz_details", "amp"], ["biz_conditional_raq_title_experiment", "raq_ruleset2_01"], ["biz_growth.biz_site_verify_with_work_email_v2", "enabled"], ["biz_growth.category_specific_claim_callouts", "status_quo"], ["biz_site_new_business_user_onboarding", "status_quo"], ["biz_site_self_serve_cpc_re_v2", "00_status_quo"], ["biz_site_yes_it_works_rollout", "yiw_impression_and_clicks_enabled"], ["contributions.biz_owner_respond_to_new_review_email", "enabled"], ["traffic_biz_details_title_v6_transactions_v3", "conditions_1"], ["traffic_category_city_category_browse_experiment", "category_city_1"], ["traffic_critical_css_on_msite", "conservative_2"], ["traffic_desc_search_title_last_updated_experiment", "with_last_updated_1"], ["traffic_index_new_pages_cross_validation", "cv_group"], ["traffic_internal_linking ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <script nonce="a6750959">
#             (function() {
#                 var main = null;
#
#                 var main=function(){window.onerror=function(k,a,c,i,f){var j=(document.getElementsByTagName("html")[0].getAttribute("webdriver")==="true"||navigator.userAgent==="selenium");var h=f&&(f.name==="ServerSideRenderingError"||f.name==="CSRFallbackError");if(j&&!h){document.body.innerHTML="<h1>Javascript Error Detected</h1>";var g=document.createElement("div");g.setAttribute("id","pastebinTraceback");var d=document.createElement("code");var e={message:k,source:a,lineno:c,colno:i,error:f};var b=document.createTextNode("JS ERROR DETECTED\n"+window.JSON.stringify(e,null,2));
# d.appendChild(b);g.appendChild(d);document.getElementsByTagName("body")[0].appendChild(g)}}};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <link href="https://s3-media0.fl.yelpcdn.com" rel="dns-prefetch"/>
# <link href="https://www.google.com" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="https://www.facebook.com" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net" rel="dns-prefetch"/>
# <link href="https://maps.googleapis.com" rel="dns-prefetch"/>
# <link href="https://js.adsrvr.org" rel="dns-prefetch"/>
# <link href="https://stats.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://idsync.rlcdn.com" rel="dns-prefetch"/>
# <script>            window.yPageStart = new Date().getTime();
# </script>
# <script>            var initialVisibilityState = document.webkitVisibilityState;
#
#                 yPerfTimings = [];
#
#                 ySitRepParams = {"uniqueRequestID": "a6750959739bea50", "zipkinTraceID": "9309b287104445c9", "cfRayID": null, "yuv_record": "GTWtXW9hE4OYFo24qgodbpsQg98O1QLtILYDZSvJQLdml45AqwymKkhSkfYef25mulmusLJgMbtMEfd15wuGyZKuQ83sVJaj", "serverStartTime": 1628976345549, "datacenter": "us-east-1", "site": "main", "isLoggedIn": false, "action": null, "servlet": "biz_details", "clientIP": "12.246.51.142", "is_internal_ip": false, "edgeStartTime": 1628976345537620, "b3Sampled": "0", "edgestageSubdomain": "_disabled", "disableBeacon": false};
#                 window.ySitRepParams['initialVisibilityState'] = initialVisibilityState;
#                 window.ySitRepParams['seoCohorts'] = [["amp_biz_details", "amp"], ["biz_conditional_raq_title_experiment", "raq_ruleset2_01"], ["biz_growth.biz_site_verify_with_work_email_v2", "enabled"], ["biz_growth.category_specific_claim_callouts", "status_quo"], ["biz_site_new_business_user_onboarding", "status_quo"], ["biz_site_self_serve_cpc_re_v2", "00_status_quo"], ["biz_site_yes_it_works_rollout", "yiw_impression_and_clicks_enabled"], ["contributions.biz_owner_respond_to_new_review_email", "enabled"], ["traffic_biz_details_title_v6_transactions_v3", "conditions_1"], ["traffic_category_city_category_browse_experiment", "category_city_1"], ["traffic_critical_css_on_msite", "conservative_2"], ["traffic_desc_search_title_last_updated_experiment", "with_last_updated_1"], ["traffic_index_new_pages_cross_validation", "cv_group"], ["traffic_internal_linking_biz_details_to_raq_searches", "enabled"], ["traffic_main_biz_experiment_toggle", null], ["traffic_nearme_optimization_experiment", "treatment"], ["traffic_nearme_redesign_experiment", "redesign_1"], ["traffic_nearme_smart_banner_experiment", "smart_banner"], ["traffic_pagination_seo_experiment", "indexed_pagination_1"], ["traffic_remove_canonical_links_on_paginated_pages", "no_canonical_2"], ["traffic_remove_cdn_sharding_exp", "remove_cdn_sharding_0"], ["traffic_search_internal_linking_experiment_v2", "linked_1"], ["traffic_search_internal_linking_home_cleaning", "linked_0"], ["traffic_search_internal_linking_service_offerings", "linked_0"], ["traffic_search_internal_linking_top_searches", "linked_0"], ["traffic_search_url_normalization", "enabled"], ["traffic_search_url_normalization_experiment_v3", "active_01"], ["traffic_top_searches_for_sitemap", "status_quo_0"], ["traffic_top_searches_through_cordite", "disabled"], ["www_biz_owner_identification", "v4"], ["www_boi_holdout_experiment_2020_q1", "prompts_enabled"], ["www_boi_modal_callouts_v2", "claim_biz_for_free"], ["yelp.www.search.traffic_bunsen_calibration_experiment", "NA_cohort_allocation_comes_from_bunsen"]];
#
#
#             (function(H){H.className=H.className.replace(/\bno-js\b/,'js');})(document.documentElement);
# </script>
# <script>            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 !function(t){function e(n){if(i[n])return i[n].exports;var r=i[n]={i:n,l:!1,exports:{}};return t[n].call(r.exports,r,r.exports,e),r.l=!0,r.exports}var i={};e.m=t,e.c=i,e.d=function(t,i,n){e.o(t,i)||Object.defineProperty(t,i,{configurable:!1,enumerable:!0,get:n})},e.n=function(t){var i=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(i,"a",i),i},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=9)}([function(t,e,i){"use strict";i.d(e,"c",function(){return r}),i.d(e,"b",function(){return s}),i.d(e,"a",function(){return o});var n=i(5),r="global",s="biz",o="biz_gtag",a=[r,"m","www",s,"webview","api","admin","error_pages",o],c=function(t,e){if(Object(n.a)(a,e)>=0)return[e,t].join(".");throw new Error("google analytics attempted to set "+t+" to an unrecognized tracker alias: "+e)};e.d=c},function(t,e,i){"use strict";function n(t){for(var e=1;e<arguments.length;e++){var i=null!=arguments[e]?arguments[e]:{},n=Object.keys(i);"function"==typeof Object.getOwnPropertySymbols&&(n=n.concat(Object.getOwnPropertySymbols(i).filter(function(t){return Object.getOwnPropertyDescriptor(i,t).enumerable}))),n.forEach(function(e){r(t,e,i[e])})}return t}function r(t,e,i){return e in t?Object.defineProperty(t,e,{value:i,enumerable:!0,configurable:!0,writable:!0}):t[e]=i,t}var s=i(2),o=i.n(s),a=i(3),c=i(4),u=i(0),f=i(6);Object.keys||o.a.shim(),Object.entries||(Object.entries=function(t){for(var e=Object.keys(t),i=new Array(e.length),n=0;n<e.length;n+=1)i[n]=[e[n],t[e[n]]];return i});var l=function(){function t(t){r(this,"clientID",void 0),r(this,"dimensions",void 0),r(this,"domain",void 0),r(this,"friendlyMap",void 0),r(this,"jsDimensions",void 0),r(this,"metrics",void 0),r(this,"temporaryDimensions",void 0),r(this,"temporaryMetrics",void 0),r(this,"trackers",void 0),r(this,"userID",void 0),r(this,"enableHighVolumeEvents",void 0),window.ga||(window.ga=function(){}),window.gtag||(window.gtag=function(){}),this.reload(t)}var e=t.prototype;return e.setupTrackers=function(){var t=this;this.friendlyMap={},this.temporaryDimensions={},this.temporaryMetrics={},Object.entries(this.trackers).forEach(function(e){var i=e[0],n=e[1];t.setupTracker(String(i),String(n))})},e.setupTracker=function(t,e){var i=this,r=n({cookieDomain:this.domain,name:t,clientId:this.clientID},this.userID?{userId:this.userID}:{});window.ga("create",e,r),this.friendlyMap[t]={},this.temporaryDimensions[t]={},this.temporaryMetrics[t]={},this.addDimensionsToFriendlyMap(t,this.dimensions),this.addDimensionsToFriendlyMap(t,this.jsDimensions),this.dimensions[t]&&Object.keys(this.dimensions[t]).forEach(function(e){i.setDimension(String(e),i.dimensions[t][e][1])}),this.metrics[t]&&Object.keys(this.metrics[t]).forEach(function(e){i.setMetric(i.metrics[t][e][0],i.metrics[t][e][1],t)}),window.ga(Object(u.d)("set",t),"anonymizeIp",!0)},e.addDimensionsToFriendlyMap=function(t,e){var i=this;e&&e[t]&&Object.keys(e[t]).forEach(function(n){i.friendlyMap[t][n]=e[t][n][0]})},e.firePageviews=function(t){var e=this;Object.keys(this.trackers).forEach(function(i){e.firePageview(String(i),t)})},e.firePageviewsWithGlobalTrackerSampled=function(t){var e=this;Object.keys(this.trackers).forEach(function(i){(i!==u.c||e.enableHighVolumeEvents)&&e.firePageview(String(i),t)})},e.firePageview=function(t,e){if(t===u.a){var i=this.trackers[t],r=n({},this.dimensions[t],this.jsDimensions[t]),s=Object.keys(r).map(function(t){return r[t]}).reduce(function(t,e){var i,r=e[0],s=e[1];return n({},t,(i={},i["dimension"+r]=null===s?s:s.toString(),i))},{}),o=this.metrics[t]||{},a=Object.keys(o).map(function(t){return o[t]}).reduce(function(t,e){var i,r=e[0],s=e[1];return n({},t,(i={},i["metric"+r]=s,i))},{});window.gtag("event","page_view",n({send_to:i,anonymize_ip:!0,cookie_domain:this.domain,client_id:this.clientID},s,a,this.userID?{user_id:this.userID}:{},e?{page_path:e}:{}))}else e&&window.ga(Object(u.d)("set",t),"page",e),window.ga(Object(u.d)("send",t),"pagev ...
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main({"clientID": "2B939C5E52CC39EE", "dimensions": {"www": {"account_level": [1, "anon"], "biz_city_state": [192, "Dayton, OH"], "biz_closed": [8, "False"], "biz_review_count": [10, "100+"], "business_id": [141, "S1RB9neqbCzIqDVbT_D9VA"], "category_paths_to_root": [94, "[['italian', 'restaurants'], ['bars', 'nightlife']]"], "content_country": [15, "US"], "decrypted_yuv_id": [3, "2B939C5E52CC39EE"], "distil": [53, null], "distil_js_enabled": [138, null], "full_url": [34, "/biz/roost-italian-dayton"], "has_canonical": [36, "False"], "integration": [14, ""], "internal_ip": [27, "False"], "is_biz_user": [129, "False"], "is_indexable": [42, "True"], "known_bot": [186, "other"], "rating": [114, 4.0], "referrer": [64, "none"], "remote_ip": [4, "12.246.51.0"], "second_level_categories": [110, "italian, bars"], "service": [107, "yelp-main"], "top_level_categories": [11, "nightlife, restaurants"], "viewport_tracking": [29, null], "ad.web_carousel_bottom_of_biz": [78, "status_quo"], "www_education_banner": [190, "enabled"], "contributions.www.remove_review_draft_modules": [183, "status_quo"], "contributions.www.war_attach_photos": [99, "enabled"], "contributions.www.war_compose_recent_photos": [102, "enabled"], "contributions.www.war_compose_redesign": [6, "enabled"], "contributions.www.war_compose_signup": [148, "disabled"], "eat24_free_delivery_banner": [45, "disabled"], "lsmoney.www.yg_raq_cards_on_search": [152, "status_quo"], "lower_promoted_delivery_threshold": [58, "reduced_to_fifteen"], "lsat.www.dropdown_header": [54, "enabled"], "lsm.www.unpakt_cta_change": [108, "unpakt_cta_enabled"], "messaging.www.composer_notifications_spam_and_hover_state": [177, "notifications_enabled"], "messaging.www.raq_cards_on_search": [61, "status_quo"], "messaging.www.yelp_guaranteed": [160, "status_quo"], "nowait_restaurant.www.no_wait_message": [106, "show_waitlist_instructions"], "pagelet_mode_www_biz_details": [24, "allow_async"], "payment.ux.www": [197, "enabled"], "platform_pickup_filter": [20, "enabled"], "readerx.web.biz_for_services": [116, "biz_status_quo"], "readerx.web.popular_dishes": [198, "highlights_popular_dishes"], "review_actions_dropdown": [2, "disabled"], "searchux.www.services_serp_card_new_layout_v0_0": [151, "status_quo"], "styleguide_buttons": [13, "status_quo"], "styleguide_typography": [159, "status_quo"], "txn.www.checkout_page_changes": [135, "enabled"], "www_biz_details_raq_sticky": [84, "enabled"], "www_current_location_suggestion": [185, "enabled"], "www_second_page_pitch": [111, "status_quo"], "www_signup_redesign": [92, "status_quo"], "yelp.www.biz_details.lazy_loading.enabled": [25, "false"], "ytp_delivery_landing": [125, "platform_pages"], "ytp_eat24_yelp_style_to_iframe": [136, "status_quo"], "ytp_order_confirmation_page": [143, "enabled"], "www_search_snippets_in_sync_with_ads": [112, "status_quo_8"], "yr_diner.www.direct_checkout_for_exact_match": [163, "disabled"]}, "global": {"account_level": [1, "anon"], "biz_closed": [4, "False"], "biz_review_count": [6, "100+"], "category_paths_to_root": [10, "[['italian', 'restaurants'], ['bars', 'nightlife']]"], "content_country": [11, "US"], "distil": [12, null], "distil_js_enabled": [13, null], "full_url": [15, "/biz/roost-italian-dayton"], "has_canonical": [16, "False"], "integration": [17, ""], "internal_ip": [18, "False"], "is_indexable": [19, "True"], "known_bot": [36, "other"], "rating": [27, 4.0], "referrer": [28, "none"], "top_level_categories": [7, "nightlife, restaurants"]}}, "domain": "yelp.com", "enable_high_volume_events": false, "ga_enabled": true, "js_dimensions": {"www": {"js_vertical_search_type": [39, null], "platform_order_type": [127, null]}, "global": {}}, "metrics": {"www": {}, "global": {}}, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "user_id": null},null);
#             })();
#     </script>
# <script async="" charset="UTF-8" data-document-language="true" data-domain-script="5fbcd417-fbc1-4fcc-abad-f622f1bba72d" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script>
#             window.yelp = window.yelp || {};
#             window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#         </script>
# <script>        (function (d, w) {
#             if (('ontouchstart' in w) || w.DocumentTouch && d instanceof w.DocumentTouch){
#                 var html = d.getElementsByTagName("html")[0];
#                 html.classList.add("touch");
#             }
#         }(document, window));
# </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="width=1224" name="viewport"/>
# <meta content="Yelp" name="application-name"/>
# <meta content="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/b8f6d9d556d5/ico/win8-tile.png" name="msapplication-TileImage"/>
# <meta content="#c41200" name="msapplication-TileColor"/>
# <meta content="https://www.yelp.com/" name="msapplication-starturl"/>
# <meta content="#c41200" name="msapplication-navbutton-color"/>
# <meta content="width=1024;height=768" name="msapplication-window"/>
# <meta content="Go to Yelp.com" name="msapplication-tooltip"/>
# <meta content="name=Find Reviews; action-uri=/; icon-uri=https://s3-media0.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task"/>
# <meta content="name=Hot New Businesses; action-uri=/openings; icon-uri=https://s3-media0.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task"/>
# <meta content="name=Yelp Deals; action-uri=/search?find_desc=deals; icon-uri=https://s3-media0.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task"/>
# <link href="android-app://com.yelp.android/yelp-app-indexing/biz/S1RB9neqbCzIqDVbT_D9VA?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate">
# <link href="ios-app://284910350/yelp//biz/S1RB9neqbCzIqDVbT_D9VA?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate">
# <meta content="Yelp" property="al:ios:app_name"/>
# <meta content="284910350" property="al:ios:app_store_id"/>
# <meta content="https://www.yelp.com/biz/roost-italian-dayton?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=apple" property="al:ios:url"/>
# <link content="#c41200" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/4374c8fd03d1/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/118ff475a341/assets/img/logos/favicon.ico" rel="shortcut icon"/>
# <link href="https://m.yelp.com/biz/roost-italian-dayton" media="only screen and (max-width: 640px)" rel="alternate">
# <meta name="critical_css_middleware"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/OpenSans-Regular.yji-1d0e82fb8ca5092d63b501cb78a3fcc5.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/OpenSans-SemiBold.yji-64284230686011de275c4b1bb4039f54.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/OpenSans-Bold.yji-49e6b3bb7a2df2996d09b9cdd89cf166.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/Poppins-Black.yji-5da432f73e49ed35ecf6e652010d4ee0.woff2" rel="preload" type="font/woff2"/>
# <script>
#     window.yelp = window.yelp || {};
#     window.yelp.critical_css_onload = function (id) {
#         this.removeAttribute("onload");
#         var el = document.querySelector('style[data-critical-css="' + id + '"]');
#         el.parentNode.removeChild(el);
#         this.rel = "stylesheet";
#     };
# </script>
# <meta id="emotion-container"/><style data-emotion-css="0 y1jj6m 7vz7be 110vchp tza3mu ardur 174jypu 1g3e5b2 16iwlls aml4xx xlzvdl m6anxm e81eai gdi06s 79elbk j67i4x qafczo 18jgzlr 4p40fi znumc2 5vnqe2 wonnhn 1wu4sus 5r1d0t 166la90 1hx6l2b n6i4z7 1x8jfzm 1dgkz3l 1qkiuob 1x0u7iy t3a4pl 15ip2po 1bcx55n 1nkqge6 8yg8ez 1w87u9d nacq06 1c2abjj 1ha1j8d 3fag8g 17hdnqh 1afdtvl 1nx1n9o 13iq1zb eysp8h 17gjwwb spph89 dh50jt a5z9dr 4dpbgc 1584uqa 854xp3 nsaq57 1st6r07 6xjl9n 1dnzbyw 15mgnpa qjdfsf 12anxc3 1p9zn9z 124jljb 21pvts r4s4k3 1p0j9vc 1x9q537 umslnc s35ftn 144by2h vybgud pqhqzm 12xo7pa yl95do 1rtqs3g jlcfqp hflfv0 ahxjws 90jz6o 1joxor6 cgwwao 1mpk29p 19sk4h4 11q1g5y bq71j2 1xxismk 13zy15n qpd7zk snedrl 1fepc68 we0w6g ac8spe 1bmgof7 1h1j0y3 ovx9y9 ga29bz 18fyvmz rzgor1 chtywg 106vfgv 1p80smk 1vhakgw 192a8l5 1o5pw2t 4jmfb6 1lzydv7">.css-y1jj6m{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-appearance:none;-moz-appearance:none;appearance:none;background-image:none;background-repeat:no-repeat;border:0;border-radius:4px;box-shadow:none;box-sizing:border-box;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;cursor:pointer;height:40px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding-bottom:8px;padding-left:16px;padding-right:16px;padding-top:8px;position:relative;text-align:center;-webkit-transition:all 0.8s;transition:all 0.8s;-webkit-transition-property:background-image,background-color,background-position,background-size,border-color,box-shadow,opacity;transition-property:background-image,background-color,background-position,background-size,border-color,box-shadow,opacity;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;width:auto;background-color:rgba(244,57,57,1);color:rgba(255,255,255,1);background-position:calc(var(--mousedown-x) - calc(var(--button-width,100px) * 200) / 2) calc(var(--mousedown-y) - calc(var(--button-width,100px) * 200) / 2);background-size:calc(var(--button-width,100px) * 200) calc(var(--button-width,100px) * 200);}.css-y1jj6m:disabled{background-color:rgba(238,238,239,1);background-image:none;border-color:rgba(238,238,239,1);box-shadow:none;color:rgba(187,186,192,1);outline:none;pointer-events:none;-webkit-transition:none;transition:none;}.css-y1jj6m:hover{box-shadow:0 1px 4px 0 rgba(0,0,0,0.3);}.css-y1jj6m:focus{box-shadow:0 0 4px 1px rgba(0,0,0,0.35);outline:none;}@media only screen and (max-width:599px){.responsive .css-y1jj6m{box-shadow:none;font-weight:normal;}}@media only screen and (max-width:780px){.responsive-biz .css-y1jj6m{box-shadow:none;font-weight:normal;}}@media (pointer:coarse){.css-y1jj6m:hover{box-shadow:none;}}.css-y1jj6m + a{display:inline-block;margin-left:12px;vertical-align:middle;}.css-y1jj6m + a:not(.css-y1jj6m),.css-y1jj6m + .button-sibling:not(.css-y1jj6m){font-size:14px;line-height:1.28571em;margin-bottom:7px;margin-top:9px;}@media only screen and (max-width:599px){.responsive .css-y1jj6m + a:not(.css-y1jj6m),.responsive .css-y1jj6m + .button-sibling:not(.css-y1jj6m){font-size:16px;line-height:1.31250em;}}.ie .css-y1jj6m > span{display:block;position:relative;}.css-y1jj6m:active{color:rgba(255,255,255,1);}.css-y1jj6m:focus{background-color:rgb(249,19,27);}.css-y1jj6m:hover{background-color:rgb(244,13,21);color:rgba(255,255,255,1);}.css-y1jj6m[data-activated='true']{background-color:rgb(244,13,21);background-image:radial-gradient(rgba(0,0,0,0.05) 1%,transparent 1%);}.css-y1jj6m[data-activated='true']:active{-webkit-transition:all 0s;transition:all 0s;background-color:rgb(244,13,21);background-image:radial-gradient(transparent 1%,transparent 1%);background-position:calc(var(--mousedown-x) - calc(var(--button-width,100px) * 1.0) / 2) calc(var(--mousedown-y) - calc(var(--button-width,100px) * 1.0) / 2);background-size:calc(var(--button-width,100px) * 1.0) calc(var ...
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-11cbada7a392558c2465.chunk.css" media="all" rel="stylesheet" type="text/css"/><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-b4f4bbd4e79685d4c595.chunk.css" media="all" rel="stylesheet" type="text/css"/><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-a408c96ed9bb7b4b5c76.chunk.css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if (IE 9)|(lt IE 9) ]> <link rel="stylesheet" type="text/css" media="all" href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/0547c86a37db/www-pkg-main.css">
#             <link rel="stylesheet" type="text/css" media="all" href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/dc8db71645fa/www-pkg-more.css"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <link href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/1f049a092068/www-pkg.css" media="all" rel="stylesheet" type="text/css"/> <!--<![endif]-->
# <link as="style" data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-1eb96b733b6aa1ff2a2f.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-363dc8f4f98e60b28ac1.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-db2859998624634ab86a.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-1ae6326678fb26ed7299.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-7cdc2b1331e7c1ed5895.chunk.css" rel="preload"/>
# <link as="style" data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-7e9c0d14ce482d02126c.chunk.css" rel="preload"/>
# <link as="style" data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-d8344e7016fb01ed0b65.chunk.css" rel="preload"/>
# <link as="style" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-f799358eb1653adf73e9.chunk.css" rel="preload"/>
# <link as="style" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-9abd4fe993968bacf7bd.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-adf4c3bf7b0e24a6a7d4.chunk.css" rel="preload"/>
# <link as="style" data-chunk="ClaimStatusGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-56da79557c18f41b1bd7.chunk.css" rel="preload"/>
# <link as="script" data-chunk="ClaimStatusGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-6903d4bd0de0de56f57c.chunk.js" rel="preload"/>
# <link as="script" data-chunk="ClaimReminderGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimReminderGQL.yji-742ab7d63dcc6e21e258.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-UnconfirmedReviewAlert" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-UnconfirmedReviewAlert.yji-48d191c3aac8a54b2c4a.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-f77e475d9bebe3acc521.chunk.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-072ae8425597786adc98.chunk.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-d69783873964906bf1a6.chunk.js" rel="preload"/>
# <link as="script" data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-12b2bcbb7cc307b4cd72.chunk.js" rel="preload"/>
# <link as="script" data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-d7c8c453c04a342a9b3f.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-ca15cb1e82d6a3f1f7b1.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-fecf61a9ca40237e3911.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-012d4b1be13e2d68a5c1.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-2021fd45d3b2a1f900fd.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-ReviewFeedWarEditor" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ReviewFeedWarEditor.yji-ef64b206660901684eeb.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-CollectionCardCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-750194ba38fb8d2bcaf4.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-5b2fa3fa8c600d09b401.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-SEOLinks" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-SEOLinks.yji-ba358ac9d096e195fd52.chunk.js" rel="preload"/><link data-chunk="ClaimStatusGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-56da79557c18f41b1bd7.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-adf4c3bf7b0e24a6a7d4.chunk.css" rel="stylesheet"/>
# <link data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-9abd4fe993968bacf7bd.chunk.css" rel="stylesheet"/>
# <link data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-f799358eb1653adf73e9.chunk.css" rel="stylesheet"/>
# <link data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-d8344e7016fb01ed0b65.chunk.css" rel="stylesheet"/>
# <link data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-7e9c0d14ce482d02126c.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-7cdc2b1331e7c1ed5895.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-1ae6326678fb26ed7299.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-db2859998624634ab86a.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-363dc8f4f98e60b28ac1.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-1eb96b733b6aa1ff2a2f.chunk.css" rel="stylesheet"/><link data-rh="true" href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/><link data-rh="true" href="https://www.facebook.com/yelp" id="sitelink-profile-facebook" itemprop="sameAs"/><link data-rh="true" href="https://twitter.com/yelp" id="sitelink-profile-twitter" itemprop="sameAs"/><link data-rh="true" href="https://www.linkedin.com/company/31517" id="sitelink-profile-linkedin" itemprop="sameAs"/><link data-rh="true" href="https://instagram.com/yelp" id="sitelink-profile-instagram" itemprop="sameAs"/><link data-rh="true" href="https://www.yelp.com" id="sitelink" itemprop="url"/><link data-rh="true" href="https://www.yelp.com/biz/roost-italian-dayton" rel="canonical"/><link data-rh="true" href="https://www.yelp.co.jp/biz/roost-italian-dayton" hreflang="ja-jp" rel="alternate"/><link data-rh="true" href="https://www.yelp.com.ar/biz/roost-italian-dayton" hreflang="es-ar" rel="alternate"/><link data-rh="true" href="https://www.yelp.cl/biz/roost-italian-dayton" hreflang="es-cl" rel="alternate"/><link data-rh="true" href="https://fi.yelp.fi/biz/roost-italian-dayton" hreflang="fi-fi" rel="alternate"/><link data-rh="true" href="https://www.yelp.at/biz/roost-italian-dayton" hreflang="de-at" rel="alternate"/><link data-rh="true" href="https://sv.yelp.fi/biz/roost-italian-dayton" hreflang="sv-fi" rel="alternate"/><link data-rh="true" href="https://fr.yelp.ca/biz/roost-italian-dayton" hreflang="fr-ca" rel="alternate"/><link data-rh="true" href="https://www.yelp.it/biz/roost-italian-dayton" hreflang="it-it" rel="alternate"/><link data-rh="true" href="https://www.yelp.com.br/biz/roost-italian-dayton" hreflang="pt-br" rel="alternate"/><link data-rh="true" href="https://zh.yelp.com.hk/biz/roost-italian-dayton" hreflang="zh-hk" rel="alternate"/><link data-rh="true" href="https://nl.yelp.be/biz/roost-italian-dayton" hreflang="nl-be" rel="alternate"/><link data-rh="true" href="https://www.yelp.es/biz/roost-italian-dayton" hreflang="es-es" rel="alternate"/><link data-rh="true" href="https://www.yelp.co.uk/biz/roost-italian-dayton" hreflang="en-gb" rel="alternate"/><link data-rh="true" href="https://www.yelp.dk/biz/roost-italian-dayton" hreflang="da-dk" rel="alternate"/><link data-rh="true" href="https://www.yelp.de/biz/roost-italian-dayton" hreflang="de-de" rel="alternate"/><link data-rh="true" href="https://fr.yelp.ch/biz/roost-italian-dayton" hreflang="fr-ch" rel="alternate"/><link data-rh="true" href="https://www.yelp.com.tw/biz/roost-italian-dayton" hreflang="zh-tw" rel="alternate"/><link data-rh="true" href="https://www.yelp.fr/biz/roost-italian-dayton" hreflang="fr-fr" rel="alternate"/><link data-rh="true" href="https://www.yelp.no/biz/roost-italian-dayton" hreflang="nb-no" rel="alternate"/><link data-rh="true" href="https://en.yelp.my/biz/roost-italian-dayton" hreflang="en-my" rel="alternate"/><link data-rh="true" href="https://www.yelp.nl/biz/roost-italian-dayton" hreflang="nl-nl" rel="alternate"/><link data-rh="true" href="https://www.yelp.com.au/biz/roost-italian-dayton" hreflang="en-au" rel="alternate"/><link data-rh="true" href="https://www.yelp.co.nz/biz/roost-italian-dayton" hreflang="en-nz" rel="alternate"/><link data-rh="true" href="https://www.yelp.cz/biz/roost-italian-dayton" hreflang="cs-cz" rel="alternate"/><link data-rh="true" href="https://www.yelp.ca/biz/roost-italian-dayton" hreflang="en-ca" rel="alternate"/><link data-rh="true" href="https://www.yelp.com/biz/roost-italian-dayton" hreflang="en-us" rel="alternate"/><link data-rh="true" href="https://en.yelp.com.hk/biz/roost-italian-dayton" hreflang="en-hk" rel="alternate"/><link data-rh="true" href="https://de.yelp.ch/biz/roost-italian-dayton" hreflang="de-ch" rel="alternate"/><link data-rh="true" href="https://fr.yelp.be/biz/roost-italian-dayton" hreflang="fr-be" re ...
# <script>/*! loadCSS. [c]2017 Filament Group, Inc. MIT License */
# (function(a){if(!a.loadCSS){a.loadCSS=function(){}}var b=loadCSS.relpreload={};b.support=(function(){var d;try{d=a.document.createElement("link").relList.supports("preload")}catch(f){d=false}return function(){return d}})();b.bindMediaToggle=function(e){var f=e.media||"all";function d(){e.media=f}if(e.addEventListener){e.addEventListener("load",d)}else{if(e.attachEvent){e.attachEvent("onload",d)}}setTimeout(function(){e.rel="stylesheet";e.media="only x"
# });setTimeout(d,3000)};b.poly=function(){if(b.support()){return}var d=a.document.getElementsByTagName("link");for(var e=0;e<d.length;e++){var f=d[e];if(f.rel==="preload"&&f.getAttribute("as")==="style"&&!f.getAttribute("data-loadcss")){f.setAttribute("data-loadcss",true);b.bindMediaToggle(f)}}};if(!b.support()){b.poly();var c=a.setInterval(b.poly,500);if(a.addEventListener){a.addEventListener("load",function(){b.poly();a.clearInterval(c)})}else{if(a.attachEvent){a.attachEvent("onload",function(){b.poly();
# a.clearInterval(c)})}}}if(typeof exports!=="undefined"){exports.loadCSS=loadCSS}else{a.loadCSS=loadCSS}}(typeof global!=="undefined"?global:this));</script>
# <script></script>
# <script>            document.cookie = "xcj=1|HNmqiPGVhFarC85BBWS8-GaRgRw8MQukC1yXmiymVRY; Domain=.yelp.com; expires=Fri, 12 Nov 2021 21:25:47 GMT; Max-Age=7776000; Path=/";
# </script>
# </link></link></link></head>
# <body class="jquery country-us logged-out react-modal-body u-bg-color-white v2" id="yelp_main_body">
# <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "98483ce09e7a9dbabdca4a32d0f1a8af90885b11", "metaData": {"projectName": "yelp_main"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1.0}, "apiKey": "ac0c27867d3912ce5714ff131041af4f", "enabled": true}</script>
# <div id="fb-root"></div>
# <div class="lang-en" id="wrap">
# <div class="page-header">
# <script nonce="a6750959">
#             (function() {
#                 var main = null;
#
#                 var main=(function(){function a(b){window.yDFP.ABP={};window.yDFP.ABP.getPixelSource=function(c){return b+"?ch="+c+"&rn="+Math.random()*11};window.yDFP.ABP.detect=function(l){var g=false;var f=2;var i=false;var h=false;function k(n,m){if(f===0||m>400){n(f===0&&g)}else{setTimeout(function(){k(n,m*2)},m*2)}}function j(){if(f!==0){return}g=!i&&h}var e=function(){f-=1;j()};var d=new Image();d.onload=e;d.onerror=function(){i=true;e()};d.src=window.yDFP.ABP.getPixelSource(1);var c=new Image();c.onload=e;
# c.onerror=function(){h=true;e()};c.src=window.yDFP.ABP.getPixelSource(2);k(l,100)};window.yDFP.ABP.abpInstalledChannel="1382551876";window.yDFP.ABP.abpNotInstalledChannel="2859285073"}window.yDFP=window.yDFP||{};window.yDFP.initABPDetection=a;return window.yDFP.initABPDetection})();
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("/px.gif");
#             })();
#     </script>
# <div id="print-masthead">
# <img alt="Yelp" class="print-bkg-img" src="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/b7e9d647188d/gfx/header_print.gif"/>
# </div>
# </div>
# <span class="offscreen" id="page-content"> </span>
# <div class="main-content-wrap main-content-wrap--full">
# <yelp-react-root><div data-hypernova-id="24090bc2-86d8-4bca-8fb7-acc3ecb7870f" data-hypernova-key="yelp_main__98483ce09e7a9dbabdca4a32d0f1a8af90885b11__yelp_main__BizDetailsApp__dynamic"><div class="toast-list__373c0__1MmrO border-color--default__373c0__r305k"></div><span class=""><!-- <a href="/biz/outlook-autumn-market-fundamental-catwalk-flimsy-roost-legibility-individualism-grocer-predestination-8">yelp</a> --></span><div class="border-color--default__373c0__r305k" data-lcp-target-id="CONSUMER_HEADER"><div class="consumer-header-container__373c0__27i8V border--bottom__373c0__219w8 border-color--default__373c0__r305k background-color--white__373c0__dd00b"><div class="consumer-header__373c0__3A_uB border-color--default__373c0__r305k"><div class="arrange__373c0__2iVWK vertical-align-middle__373c0__2sr2a border-color--default__373c0__r305k"><div class="logo-arrange-unit__373c0__1LA_K arrange-unit__373c0__3XPkE border-color--default__373c0__r305k"><div class="margin-r4__373c0__2qO01 margin-sm-r0__373c0__Ql2KW border-color--default__373c0__r305k"><div class="logo__373c0__14Oid logo-image__373c0__3gPZF logo-container__373c0__1Rmgw border-color--default__373c0__r305k" data-analytics-label="logo" id="logo" style="background-image:url(https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_design_cdn/7ef71bf77a33/assets/img/brand/logo_desktop.svg)"><a class="logo-link__373c0__3ktru css-5r1d0t" href="/" name="" rel="" role="link" target="">Yelp</a></div></div></div><div class="search-suggest-arrange-unit__373c0__1v2fg arrange-unit__373c0__3XPkE arrange-unit-fill__373c0__38Zde border-color--default__373c0__r305k"><div class="search-suggest-container-outer__373c0__3E8zI border-color--default__373c0__r305k"><div class="search-suggest-container-inner__373c0__1pdAU border-color--default__373c0__r305k"><div class="arrange__373c0__2iVWK gutter-2__373c0__1a5Xm border-color--default__373c0__r305k"><div class="arrange-unit__373c0__3XPkE arrange-unit-fill__373c0__38Zde border-color--default__373c0__r305k"><div class="search-suggest__373c0__1Ot-z"><div class=""><form action="/search" class="find-near-form__373c0__2t5ip" id="header_find_form" method="get" role="search"><div class="undefined arrange__373c0__2iVWK border-color--default__373c0__r305k"><div class="arrange-unit__373c0__3XPkE arrange-unit-fill__373c0__38Zde border-color--default__373c0__r305k"><div class="find-near-arrange__373c0__1dL92 arrange__373c0__2iVWK layout-equal__373c0__18sxP border-color--default__373c0__r305k"><div class="find-near-arrange-unit__373c0__jxc6J arrange-unit__373c0__3XPkE border-color--default__373c0__r305k"><label class="label__373c0__hSdlp pseudo-input__373c0__8coNC pseudo-input__373c0__30UmM pseudo-input--find-near__373c0__3JwPV pseudo-input--find__373c0__1GHu1" for="search_description"><span class="pseudo-input-text__373c0__2GGxM display--inline__373c0__31SCF border-color--default__373c0__r305k"><div class="pseudo-input-icon-container__373c0__23ECg margin-r1-5__373c0__d6TAd border-color--default__373c0__r305k"><span aria-hidden="false" aria-label="Find" class="icon--24-search-v2 pseudo-input-icon__373c0__3Yqz8 css-1mpk29p" role="img"><svg class="icon_svg" height="24" width="24"><path d="M21.853 20.355l-3.444-3.443a9.428 9.428 0 10-16.761-6.171 9.428 9.428 0 0015.348 7.586l3.443 3.442a1 1 0 101.414-1.414zM5.82 16.245a7.429 7.429 0 115.253 2.175 7.38 7.38 0 01-5.253-2.176z"></path></svg></span></div></span><div class="border-color--default__373c0__r305k overflow--hidden__373c0__3E2fM"><div class="typeahead__373c0__SWfg- border-color--default__373c0__r305k"><input aria-hidden="true" autocomplete="off" class="input__373c0__3M_CJ input__373c0__wmiFA hidden-input__373c0__2tdro" disabled="" placeholder=" " spellcheck="false" tabindex="-1" type="text" value=""/><input aria-autocomplete="list" autocomplete="off" class="input__373c0__3M_CJ input__373c0__wmiFA original-input__373c0__3DS3h" data-testid="suggest-desc-input" id="search_description" name="find_desc" placeholder= ...
# <script data-hypernova-id="24090bc2-86d8-4bca-8fb7-acc3ecb7870f" data-hypernova-key="yelp_main__98483ce09e7a9dbabdca4a32d0f1a8af90885b11__yelp_main__BizDetailsApp__dynamic" type="application/json"><!--{"bizDetailsPageProps":{"actionBarControllerProps":{"businessId":"S1RB9neqbCzIqDVbT_D9VA","currentUserDidSave":false,"isLoggedIn":false,"saveTooltipText":null,"shareBusinessModalProps":{"facebookUrl":"http://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Froost-italian-dayton%3Futm_campaign%3Dwww_business_share_popup%26utm_medium%3Dsocial%26utm_source%3Dfacebook.com","twitterUrl":"https://twitter.com/share?text=Check+out+Roost+Italian+on+%40yelp&amp;url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Froost-italian-dayton%3Futm_campaign%3Dwww_business_share_popup%26utm_medium%3Dsocial%26utm_source%3Dtwitter.com","shareUrl":"https://www.yelp.com/biz/roost-italian-dayton?utm_campaign=www_business_share_popup&amp;utm_medium=copy_link&amp;utm_source=(direct)","contentType":"business","sendToFriendProps":{"loggedIn":false,"submitUrl":"/send_to_friend/business/S1RB9neqbCzIqDVbT_D9VA","submitCsrfToken":"b'582eecf431042406d6890bd3f262fe37952cb3c3bf8b3c5f77770c385058ec0c'","findFriendsUrl":"/find_friends/","searchForFriendsUrl":"/send_to_friend/friend_type_ahead_v2","searchForFriendsCsrfToken":"b'40d4fd2c11c8113f58ca31ce59503e5d36a0e5c052520c2972c282ef2ebd4516'"}},"postingBlockedModalProps":null,"collectionSaveModalProps":{"collectionListUrl":"/collection/user/list_save_collections?item_id=S1RB9neqbCzIqDVbT_D9VA","createCollectionCsrfToken":"3fc29ea92f417caf925c9e041e5fc2f195a5ff40ca4df0478aba48a378b89d58","createCollectionUrl":"/collection/user/new","itemId":"S1RB9neqbCzIqDVbT_D9VA","removeItemCsrfToken":"155d7c088c947d02efe6889edb203d8ef73983d0b754736ef9590a3acdcf3c98","removeItemUrl":"/collection/user/item/remove","saveItemCsrfToken":"16d7a031384d4b2859ad7c4bbb210cbcd51248ccb852ed59118ed588156c35d8","saveItemUrl":"/collection/user/item/add"}},"adBizComparisonProps":null,"adCarouselAboveReviewProps":null,"adCarouselBelowReviewProps":null,"adUnitsAboveReviewProps":null,"adUnitsBelowReviewProps":null,"adUnitsSidebarProps":null,"autoOpeningMessagingModalProps":{"iframeUrls":{"mtb_search_ad":"/mtb_composer/business/S1RB9neqbCzIqDVbT_D9VA/entry_point/mtb_search_ad?source_request_id=a6750959739bea50","mtb_landing_page":"/mtb_composer/business/S1RB9neqbCzIqDVbT_D9VA/entry_point/mtb_landing_page?source_request_id=a6750959739bea50","third_party_deep_link":"/mtb_composer/business/S1RB9neqbCzIqDVbT_D9VA/entry_point/third_party_deep_link?source_request_id=a6750959739bea50","mtb_search_action":"/mtb_composer/business/S1RB9neqbCzIqDVbT_D9VA/entry_point/mtb_search_action?source_request_id=a6750959739bea50"}},"bizContactInfoProps":{"businessId":"S1RB9neqbCzIqDVbT_D9VA","businessWebsite":{"linkText":"roostitalian.com","href":"/biz_redir?url=https%3A%2F%2Fwww.roostitalian.com%2Flocation%2Froost-modern-italian%2F&amp;cachebuster=1628976346&amp;website_link_type=website&amp;src_bizid=S1RB9neqbCzIqDVbT_D9VA&amp;s=8fa53f6d2c862fcf7dac03e6da9bb79ba0d89c4ae1768fec2a56d2a573858e3c","rel":"noopener nofollow","target":"_blank"}},"bizDiscoveryTopPitchProps":null,"bizPortfolioProps":null,"bizQuestionsProps":null,"businessAlertProps":null,"businessId":"S1RB9neqbCzIqDVbT_D9VA","businessIsAdvertiser":false,"businessName":"Roost Italian","businessPostsCarouselProps":null,"callToActionProps":null,"checkInOfferProps":null,"cityPageAlias":"dayton-oh-us","claimTeaserReviewSectionProps":null,"claimTeaserSidebarProps":null,"claimReminderProps":null,"claimStatusGQLProps":null,"collectionCardCarouselProps":{"collections":[{"url":"/collection/SnIAD36NBTqhgZTTGZlcgw","itemCount":8,"name":"Dayton Ohio - Eat, Drink, Be Happy","owner":{"displayName":"Amanda B."},"photos":[{"sourceUrl":"https://s3-media0.fl.yelpcdn.com/bphoto/tX7DhuIoT56qS-PbUCApDg/300s.jpg"}]},{"url":"/collection/MYqSUEUiWBvO9vGf6F6k2A","itemCount":10,"name":"Dayton’s Best","owner":{"displayName":"Tania B ...
# </div>
# <div id="page-popups" style="display: none;">
# </div>
# </div>
# <script>            yConfig = {"isLoggedIn": false, "isLive": true, "isSitRepEnabled": true, "isWebviewRequest": false, "webviewInfo": {}, "webviewFlow": null, "enabledSitRepChannels": {"ad_syndication": true, "ytp_session_events": true, "highlights": true, "ad_syndication_cookie_sync_errors": true, "call_to_action": true, "biz_services": true, "biz_map_view": true, "traffic_quality": true, "biz_directions": true, "vertical_search_platform": true, "vertical_search_reservation": true, "search_suggest_events": true, "message_the_business": true}, "cookies": {"AD_CLICKS": "adc", "ADMIN_CM_SCOREBOARD_SETTINGS": "acms", "ADMIN_SEARCH_USERDATA": "ud", "APP_PITCH_CLOSED": "ap", "XCJ": "xcj", "COOKIE_INFO": "cim", "DEBUG": "debug", "DISMISSIBLE_MESSAGE_COOKIE": "dm", "EXPR_OVERRIDE": "expr", "HOMEPAGE_SERVICE_ACTIVITY_FEED": "hsfd", "LOCATION": "location", "MESSAGE_SENDER_PASSED_CAPTCHA": "mspc", "PREVIOUS_UNIQUE_REQUEST_ID": "pid", "PRIVACY_POLICY_NOTICE": "ppn", "QUANTCAST": "qntcst", "RECENT_LOCATIONS": "recentlocations", "RESERVATION_SEARCH_PARAMS": "rsp", "SIGNUP_TRACK": "strack", "UPGRADES_IN_ARREARS": "uia", "USED_LOCALE_SELECTOR": "used_locale_selector", "MO_MAP": "mmp"}, "imageUrls": {"mapMarkers": "https://s3-media0.fl.yelpcdn.com/assets/2/www/img/fca83ddb80f2/map/map_markers_sprite.png", "stars": "https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_design_web/9bec2045845c/assets/img/stars/stars.png"}, "comscore": {"c1": 2, "c2": 7130511, "c3": "", "c4": "", "c5": "", "c6": "", "c15": ""}, "uaInfo": {"device": {"family": "Other", "brand": null, "model": null}, "os": {"family": "Other", "major": null, "minor": null, "patch": null, "patch_minor": null}, "string": "python-requests/2.24.0", "user_agent": {"family": "Python Requests", "major": "2", "minor": "24", "patch": null}, "attributes": {}}, "isBugsnagEnabled": true, "deprecatedEncryptedYUV": "GTWtXW9hE4OYFo24qgodbpsQg98O1QLtILYDZSvJQLdml45AqwymKkhSkfYef25mulmusLJgMbtMEfd15wuGyZKuQ83sVJaj", "yelpcodeTemplateVersion": "98483ce09e", "vendorExternalURLs": {}, "isClientErrorsEnabled": false, "cookieDomain": ".www.yelp.com", "uniqueRequestId": "a6750959739bea50", "recaptchaPublicKey": "6Le5OSYTAAAAADy8seTrWT0eqpS795iV32Gm9Ag1", "recaptchaV3PublicKey": "6Le2lKQUAAAAAMMHRuHPaDwOMSodMg2FiVTGSw2Y", "hcaptchaSitekey": "6660d4df-1884-4ac6-a933-e5f3bd460946", "googlePlacesUrl": "//maps.googleapis.com/maps/api/js?key=AIzaSyByT6TXVL4jSf0MrzRwg0eG66A8-P4r0ps\u0026language=en\u0026libraries=places"};
# </script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[6,5,35,14,2,9,7,0,4,22,32,16,29,27,18,26,30]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["ClaimStatusGQL","ClaimReminderGQL","components-UnconfirmedReviewAlert","components-BizPageConfigurableAlertsGQL","OnTheMenuGQL","MapBoxV2GQL","BizHoursGQL","components-MoreBusinessInfo","components-ServiceUpdateSummaryGQL","components-BizQuestionsGQL","components-Reviews","components-ReviewFeedWarEditor","components-CollectionCardCarousel","components-RelatedBusinessesCarousel","components-SEOLinks"]}</script>
# <script async="" data-chunk="ClaimStatusGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-6903d4bd0de0de56f57c.chunk.js"></script>
# <script async="" data-chunk="ClaimReminderGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimReminderGQL.yji-742ab7d63dcc6e21e258.chunk.js"></script>
# <script async="" data-chunk="components-UnconfirmedReviewAlert" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-UnconfirmedReviewAlert.yji-48d191c3aac8a54b2c4a.chunk.js"></script>
# <script async="" data-chunk="components-BizPageConfigurableAlertsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-f77e475d9bebe3acc521.chunk.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-072ae8425597786adc98.chunk.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-d69783873964906bf1a6.chunk.js"></script>
# <script async="" data-chunk="MapBoxV2GQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-12b2bcbb7cc307b4cd72.chunk.js"></script>
# <script async="" data-chunk="BizHoursGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-d7c8c453c04a342a9b3f.chunk.js"></script>
# <script async="" data-chunk="components-MoreBusinessInfo" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-ca15cb1e82d6a3f1f7b1.chunk.js"></script>
# <script async="" data-chunk="components-ServiceUpdateSummaryGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-fecf61a9ca40237e3911.chunk.js"></script>
# <script async="" data-chunk="components-BizQuestionsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-012d4b1be13e2d68a5c1.chunk.js"></script>
# <script async="" data-chunk="components-Reviews" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-2021fd45d3b2a1f900fd.chunk.js"></script>
# <script async="" data-chunk="components-ReviewFeedWarEditor" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-ReviewFeedWarEditor.yji-ef64b206660901684eeb.chunk.js"></script>
# <script async="" data-chunk="components-CollectionCardCarousel" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-750194ba38fb8d2bcaf4.chunk.js"></script>
# <script async="" data-chunk="components-RelatedBusinessesCarousel" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-5b2fa3fa8c600d09b401.chunk.js"></script>
# <script async="" data-chunk="components-SEOLinks" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-SEOLinks.yji-ba358ac9d096e195fd52.chunk.js"></script>
# <script>            window.yelp = window.yelp || {};
#             window.yelp.reactRenderMode = "legacy";
# </script>
# <script crossorigin="anonymous" integrity="sha384-FbHUaR69a828hqWjPw4PFllFj1bvveKOTWORGkyosCw720HXy/56+2hSuQDaogMb" nonce="a6750959" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/6fef55c62df3/assets/vendor/babel-polyfill/6.23.0/polyfill.min.js"></script><script nonce="a6750959">
#         yConfig = window.yConfig || {};
#         yConfig.vendorExternalURLs = yConfig.vendorExternalURLs || {};
#         </script><script crossorigin="anonymous" integrity="sha384-qn+ML/QkkJxqn4LLs1zjaKxlTg2Bl/6yU/xBTJAgxkmNGc6kMZyeskAG0a7eJBR1" nonce="a6750959" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/f808b8e8ab51/assets/vendor/react/16.8.6/umd/react.production.min.js"></script><script crossorigin="anonymous" integrity="sha384-85IMG5rvmoDsmMeWK/qUU4kwnYXVpC+o9hoHMLi4bpNR+gMEiPLrvkZCgsr7WWgV" nonce="a6750959" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/fad5842bd019/assets/vendor/react-dom/16.8.6/umd/react-dom.production.min.js"></script><script crossorigin="anonymous" nonce="a6750959" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp_main_webpack_runtime.yji-3e6aeb42c8c3775eb83e.js"></script><script crossorigin="anonymous" nonce="a6750959" src="https://s3-media0.fl.yelpcdn.com/assets/public/common_chunk.yji-8f53ab3cbd3fb8926a7c.chunk.js"></script><script crossorigin="anonymous" nonce="a6750959" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_core.yji-ebfeb873692d8f8c5f25.chunk.js"></script><script crossorigin="anonymous" nonce="a6750959" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_react_biz_details_v2.yji-cafe751b895f269a44c9.chunk.js"></script><script nonce="a6750959">
#                 yConfig.vendorExternalURLs["plugin-detect"]=['https://s3-media0.fl.yelpcdn.com/assets/2/www/js/bfd62b330c7a/assets/vendor_external/plugin-detect-0.6.3.min.js']
#
#                 yConfig.vendorExternalURLs["fast-click"]=['https://s3-media0.fl.yelpcdn.com/assets/2/www/js/960df06ce458/assets/vendor_external/fastclick.min.js']
#                 yelp.www.pages.initSitrep(true);
# yelp.www.pages.initBugsnag();
# window.YelpReactBizDetailsV2.hydrateReactComponents();
# </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 main = function (serviceName, sha) {window.yelp_react = {serviceName: serviceName,sha: sha};};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("yelp_main.www","98483ce09e7a9dbabdca4a32d0f1a8af90885b11");
#             })();
#     </script>
# <script>                window.webLogInfo = true;
# </script>
# <script>                window.yClientLogInfo = true;
# </script>
# <script nonce="a6750959">
#             (function() {
#                 var main = null;
#
#                 var main=function(){if(["iPhone","iPod","iPad"].indexOf(navigator.platform)===-1||!window.requestAnimationFrame){return}window.bannerDetectionInitialScroll=window.bannerDetectionInitialScroll||window.scrollY||-100;requestAnimationFrame(function(){window.scrollTo(0,-100);requestAnimationFrame(function(){window.scrollBy(0,1);requestAnimationFrame(function(){window.userHasYelpApp=!window.scrollY;window.scrollTo(0,window.bannerDetectionInitialScroll)})})})};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <script>            yConfig.csrf = {"FacebookTokenRefresh": "432699045f1027266d8be94a9b40190769d8d5bfd0626f148ec68c04e85c8f7e"};
# </script>
# <script nonce="a6750959">
#             (function() {
#                 var main = null;
#
#                 var main=function(a){window.yelp_bunsen_logger.bunsen_logger.init(a)};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main({"context": [{"schema_id": 279661, "payload_data": {"guv": "2B939C5E52CC39EE"}}, {"schema_id": 171864, "payload_data": {"unique_request_id": "9309b287104445c9"}}, {"schema_id": 280941, "payload_data": {"internal_ip": false}}, {"schema_id": 338431, "payload_data": {"internal_ip": false}}, {"schema_id": 280599, "payload_data": {"language": "en", "country": "US"}}, {"schema_id": 338430, "payload_data": {"language": "en", "country": "US"}}, {"schema_id": 283288, "payload_data": {"user_id": null}}, {"schema_id": 311701, "payload_data": {"platform": "www"}}, {"schema_id": 338439, "payload_data": {"platform": "www"}}, {"schema_id": 284174, "payload_data": {"normed_app_version": "unknown"}}, {"schema_id": 284175, "payload_data": {"normed_device_type": "UnknownDevice"}}, {"schema_id": 312263, "payload_data": {"product": "consumer", "product_version": "r98483ce09e-deploy-friday-afternoon"}}, {"schema_id": 338440, "payload_data": {"product": "consumer", "product_version": "r98483ce09e-deploy-friday-afternoon"}}, {"schema_id": 309536, "payload_data": {"previous_unique_view_id": null, "unique_view_id": "9309b287104445c9"}}, {"schema_id": 338432, "payload_data": {"previous_unique_view_id": null, "unique_view_id": "9309b287104445c9"}}, {"schema_id": 311448, "payload_data": {"biz_user_id_encid": null}}, {"schema_id": 311702, "payload_data": {"os_name": "unknown", "os_version": "x.x.x"}}, {"schema_id": 338437, "payload_data": {"os_name": "unknown", "os_version": "x.x.x"}}, {"schema_id": 306745, "payload_data": {"name": "www"}}, {"schema_id": 311859, "payload_data": {"page_id": "69829c2204ae7e5cc2f70a435b13c359639f2aa2"}}, {"schema_id": 311757, "payload_data": {"is_interactive": true}}, {"schema_id": 338434, "payload_data": {"is_interactive": true}}, {"schema_id": 311510, "payload_data": {"user_id_encid": null}}, {"schema_id": 338441, "payload_data": {"user_id_encid": null}}, {"schema_id": 311758, "payload_data": {"interface_name": "python_requests", "interface_version": "2.24.x"}}, {"schema_id": 338435, "payload_data": {"interface_name": "python_requests", "interface_version": "2.24.x"}}, {"schema_id": 312281, "payload_data": {"offset": null}}, {"schema_id": 338436, "payload_data": {"offset": null}}, {"schema_id": 311756, "payload_data": {"hardware_model": null}}, {"schema_id": 338433, "payload_data": {"hardware_model": null}}, {"schema_id": 321983, "payload_data": {"user_advertising_id": null}}, {"schema_id": 352511, "payload_data": {"source": "yelp-main"}}]});
#             })();
#     </script>
# </body>
# </html>

# %%
result = soup.findAll(class_='comment__373c0__1M-px css-n6i4z7')
print(result)
# Out:
# []

# %%
reviews = []
for result in results:
    reviews.append(result.find('span').text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7557bffac726> in <module>
#       1 reviews = []
# ----> 2 for result in results:
#       3     reviews.append(result.find('span').text)
#
# NameError: name 'results' is not defined

# %%
for review in reviews:
    print(review,'\n')

# %% [markdown]
# ## Making our DataFrame using Pandas
#  **Pandas**- pandas provides data structures and operations for manipulating numerical tables and time series.
#
# **Array**- an array is a collection of data stored in a spacific location.

# %%
df = pd.DataFrame(np.array(reviews), columns =['Reviews'])
df.tail()
# Out:
# Empty DataFrame
# Columns: [Reviews]
# Index: []

# %% [markdown]
# # Creating some Metrics
#
# ##### .apply is used to add data to our DataFrame
# ##### .split serperates each word in a string into an item

# %% [markdown]
# #### 1.) How many word are in each review?

# %%
df['word_count'] = df['Reviews'].apply(lambda x: len(str(x).split ()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ea782f96e8c6> in <module>
# ----> 1 df['word_count'] = df['Reviews'].apply(lambda x: len(str(x).split ()))
#
# NameError: name 'df' is not defined

# %%
df.head()

# %% [markdown]
# #### 2.) How many charerters are in each review?

# %%
df['char_count'] = df['Reviews'].str.len()

# %% [markdown]
# ### What is the average amount of words lenght in each review?
#
# #### def = Defining a Function

# %%
def average_words(x):
    words = x.split()
    return sum(len(word) for word in words) / len(words)

# %%
df['Reviews'].apply(lambda x: average_words(x))

# %%
df['Average_Word_Lenght'] = df['Reviews'].apply(lambda x: average_words(x))

# %% [markdown]
# ### How Many Stop Word are in Each Review?
#
# **Stopwords** - Stopwords are the words in any language which does not add much meaning to a sentence. They can safely be ignored without sacrificing the meaning of the sentence.

# %%
## importing a stop words list from the "Natural Language Toolkit"
from nltk.corpus import stopwords

# %%
## creating our variable
stop_words = stopwords.words('english')

# %%
## seeing what is stofred in the stopwords list
stop_words

# %%
## How many word are stored in the list
len(stop_words)

# %%
df['Reviews'].apply(lambda x: len([word for word in x.split() if word.lower() in stop_words]))

# %%
df['stop_word_count'] = df['Reviews'].apply(lambda x: len([word for word in x.split() if word.lower() in stop_words]))

# %%
df['stop_word_count'] / df['word_count']

# %%
df['stop_word_rate'] = df['stop_word_count'] / df['word_count']

# %%
df.head(11)

# %%
df.sort_values(by='word_count')

# %%
df.describe()

# %% [markdown]
# # Staged Based Data Cleaning

# %%
## making all the letters lowercase in each review
df['Reviews'].apply(lambda x: ''.join(word.lower() for word in x.split()))

# %%
df['lowercase'] = df['Reviews'].apply(lambda x: ''.join(word.lower() for word in x.split()))

# %%
# removing exclamations and spaces
df['lowercase'].str.replace('[^\w\s]', '')

# %% [markdown]
# Tokenization = blocks of text are divided into sperate words and picies of punctuation

# %%
# removing punctuation
df['Punctuation'] = df['lowercase'].str.replace('[^\w\s]', '')

# %%
df.head()

# %%
# removing stop_words 
df['Punctuation'].apply(lambda x: " ".join( word for word in x.split() if word not in stop_words))

# %%
#adding to our df 
df['stopwords'] = df['Punctuation'].apply(lambda x: ''.join (x for x in x.split() if x not in stop_words))

# %%
df.head()

# %%
# joining our reviews back together
" ".join(df['stopwords'])

# %%
# creating an array
pd.Series(" ".join(df['stopwords']).split())

# %%
stop_words

# %%
freq = pd.Series(''.join(df['review_nopunc_nostop']).split()).value_counts() [:30]
