# %%
# we will use pandas create our data frame
import pandas as pd
# we will use Beautiful Soup fromto pull data from the HTML
from bs4 import BeautifulSoup
# requests will allow us to pull data from Yelp
import requests
# use to perform numerical operations 
import numpy as np

# %%
r = requests.get('https://www.pewresearch.org/social-trends/fact-sheet/the-data-on-women-leaders/')
print(r)
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '<!doctype html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no">\n\t<link rel="profile" href="http://gmpg.org/xfn/11">\n\t<script type="text/javascript">/* wpack.io publicPath */window.__wpackIoprcParentdist=\'https://www.pewresearch.org/social-trends/wp-content/themes/prc_parent/dist/\';</script><script type="text/javascript">/* wpack.io publicPath */window.__wpackIoprcParentdist=\'https://www.pewresearch.org/social-trends/wp-content/themes/prc_parent/dist/\';</script><script type="text/javascript">/* wpack.io publicPath */window.__wpackIoprcBlocksLibrarydist=\'https://www.pewresearch.org/social-trends/wp-content/plugins/prc-block-library/dist/\';</script><script type="text/javascript">/* wpack.io publicPath */window.__wpackIoprcBlocksLibrarydist=\'https://www.pewresearch.org/social-trends/wp-content/plugins/prc-block-library/dist/\';</script><script type="text/javascr
# ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# ...

# %%
reviews = []
for result in results:
    reviews.append(result.find('span').text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-7557bffac726> in <module>
#       1 reviews = []
# ----> 2 for result in results:
#       3     reviews.append(result.find('span').text)
#
# NameError: name 'results' is not defined

# %%
for review in reviews:
    print(review,'\n')
